# %%
# %%
# %%
import pandas as pd

df = pd.read_csv("tips.csv")
df.head()


# %%

# %%
df.info()


# %%

# %%
df.describe()


# %%

# %%
df.columns


# %%

# %%
df.shape


# %%

# %%
df["total_bill"]
df[["total_bill", "tip"]]


# %%

# %%
df[df["total_bill"] > 30]
df[df["sex"] == "Female"]
df[(df["total_bill"] > 20) & (df["time"] == "Dinner")]


# %%

# %%
df[(df["total_bill"] > 40) & (df["size"] == 3)].sort_values("total_bill", ascending=False)


# %%



# %%
df[(df["total_bill"] > 40) & (df["size"] == 3)]["tip"].mean()


# %%

# %%
df["tip_pct"] = df["tip"] / df["total_bill"] * 100

df[(df["total_bill"] > 40) & (df["size"] == 3)].sort_values("tip_pct", ascending=False)


# %%


# %%
df.groupby("sex")["tip"].mean()


# %%


# %%
df.groupby("day")["total_bill"].mean()


# %%


# %%
df.groupby("time")[["total_bill", "tip"]].agg(["mean", "sum"])


# %%

# %%
df.groupby(["day", "sex"])["tip"].mean()


# %%


# %%
df.groupby("day")["tip"].mean()


# %%

# %%
df.groupby("time")["tip"].mean()


# %%

# %%
df.groupby("time")["tip"].mean().sort_values(ascending=False)


# %%

# %%
df.groupby("day")["tip"].mean().sort_values(ascending=False)


# %%

# %%
df["tip_percentage"] = df["tip"] / df["total_bill"] * 100
df.head()

# %%
# %%
df["bill_per_person"] = df["total_bill"] / df["size"]
df.head(244)


# %%

# %%
df["bill_per_person"] = df["total_bill"] / df["size"]
df.sample(10)


# %%

# %%
df["bill_per_person"] = df["total_bill"] / df["size"]
df.tail(10)


# %%

# %%
df.groupby("day")["tip"].mean().sort_values(ascending=False)


# %%

# %%
df.groupby("sex")["tip_percentage"].mean().sort_values(ascending=False)


# %%

# %%
df.groupby("size")["tip_percentage"].mean().sort_values(ascending=False)


# %%

# %%
df.groupby("time")["tip"].mean().sort_values(ascending=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB
# time
# Dinner    3.102670
# Lunch     2.728088
# Name: tip, dtype: float64
